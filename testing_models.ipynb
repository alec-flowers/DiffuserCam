# %%
# %load_ext autoreload
# %autoreload 2
from scripts.evaluation import evaluate
from diffcam.util import DATAPATH, RECONSTRUCTIONPATH, print_image_info, resize, rgb2gray
import os
# Out:
# d:\EPFL_Master\MA3\MFSP\DiffuserCam\diffcam_env\lib\site-packages\pycsou-1.0.6-py3.9.egg\pycsou\linop\sampling.py:945: SyntaxWarning: "is" with a literal. Did you mean "=="?
# d:\EPFL_Master\MA3\MFSP\DiffuserCam\diffcam_env\lib\site-packages\pycsou-1.0.6-py3.9.egg\pycsou\linop\sampling.py:965: SyntaxWarning: "is" with a literal. Did you mean "=="?
# d:\EPFL_Master\MA3\MFSP\DiffuserCam\diffcam_env\lib\site-packages\pycsou-1.0.6-py3.9.egg\pycsou\linop\sampling.py:967: SyntaxWarning: "is" with a literal. Did you mean "=="?
# d:\EPFL_Master\MA3\MFSP\DiffuserCam\diffcam_env\lib\site-packages\pycsou-1.0.6-py3.9.egg\pycsou\linop\sampling.py:969: SyntaxWarning: "is" with a literal. Did you mean "=="?
# d:\EPFL_Master\MA3\MFSP\DiffuserCam\diffcam_env\lib\site-packages\pycsou-1.0.6-py3.9.egg\pycsou\linop\sampling.py:945: SyntaxWarning: "is" with a literal. Did you mean "=="?
# d:\EPFL_Master\MA3\MFSP\DiffuserCam\diffcam_env\lib\site-packages\pycsou-1.0.6-py3.9.egg\pycsou\linop\sampling.py:965: SyntaxWarning: "is" with a literal. Did you mean "=="?
# d:\EPFL_Master\MA3\MFSP\DiffuserCam\diffcam_env\lib\site-packages\pycsou-1.0.6-py3.9.egg\pycsou\linop\sampling.py:967: SyntaxWarning: "is" with a literal. Did you mean "=="?
# d:\EPFL_Master\MA3\MFSP\DiffuserCam\diffcam_env\lib\site-packages\pycsou-1.0.6-py3.9.egg\pycsou\linop\sampling.py:969: SyntaxWarning: "is" with a literal. Did you mean "=="?

# %%
data = 'our_images'
n_files = 1          # None yields all :-)
algo = 'glasso'
n_iter = 10
gray = False
lambda_ = 1e-6
delta = 5

downsample = 4
disp = 50
flip = False
bayer = False
bg = None
rg = None
gamma = None
save = True
plot = True
single_psf = False

psf_fp = rf'{str(DATAPATH)}{os.sep}psf{os.sep}psf_rgb_ours.png'

evaluate(data, n_files, psf_fp, algo, lambda_, delta, n_iter, downsample, disp, flip, gray, bayer, bg, rg, gamma, save, plot, single_psf)
# Out:
# Number of files :  1
# dimensions : (760, 1014, 3)
# data type : float32
# max  : 0.012142143212258816
# min  : 0.0
# mean : 0.0003967037773691118
#
# Looping through files...
#
# -----------------------------
#  Evaluating img1_rgb...
# -----------------------------
# setup time : 36.194923877716064 s
# proc time : 18.378509044647217 s
# WARNING: Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Files saved to : D:\EPFL_Master\MA3\MFSP\DiffuserCam\data\reconstruction\uncropped_img1_glasso_10_2912292021_01h54.png
#
# Ground truth shape: (228, 341, 3)
# Reconstruction shape: (228, 341, 3)
#
# Files saved to : D:\EPFL_Master\MA3\MFSP\DiffuserCam\data\reconstruction\img1_glasso_10_2912292021_01h54.png
# d:\EPFL_Master\MA3\MFSP\DiffuserCam\diffcam\metric.py:22: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   return peak_signal_noise_ratio(image_true=true, image_test=est)
# MSE: 0.20052537381503577
#
# PSNR: 6.978306653848122
#
# SSIM: 0.14041022956371307
#
# LPIPS: 0.920167863368988
#
# -----------------------------
#  Average scores
# -----------------------------
#
# MSE (avg) 0.20052537381503577
# PSNR (avg) 6.978306653848122
# SSIM (avg) 0.14041023
# LPIPS (avg) 0.920167863368988
# Logs saved to: D:\EPFL_Master\MA3\MFSP\DiffuserCam\data\logs\glasso_1e-06_2912292021_01h55
# d:\EPFL_Master\MA3\MFSP\DiffuserCam\diffcam_env\lib\site-packages\scikit_image-0.19.0rc0-py3.9-win-amd64.egg\skimage\_shared\utils.py:214: UserWarning: Inputs have mismatched dtype.  Setting data_range based on im1.dtype.
#   return func(*args, **kwargs)
